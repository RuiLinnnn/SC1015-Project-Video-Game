# %% [markdown]
# # Machine Learning Techniques

# %% [markdown]
# Linear Regression

# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
total_count_total_sale = pd.read_csv('total-count-total-sale.csv')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

X = pd.DataFrame(total_count_total_sale['Total_Count'])
y = pd.DataFrame(total_count_total_sale['Total_Sales'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

print("Train Set :", X_train.shape, y_train.shape)
print("Test Set  :", X_test.shape, y_test.shape)

linreg = LinearRegression()  
linreg.fit(X_train, y_train)

print('Intercept of Regression \t: y = ', linreg.intercept_)
print('Coefficients of Regression \t: X = ', linreg.coef_)
print()

# Predict Total values corresponding to HP Train
y_train_pred = linreg.predict(X_train)

print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
y_test_pred = linreg.predict(X_test)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()


f, axes = plt.subplots(1, 2, figsize=(16, 8))
axes[0].scatter(X_train, y_train)
axes[0].scatter(X_train, y_train_pred, color = "r")
axes[1].scatter(X_test, y_test, color = "green")
axes[1].scatter(X_test, y_test_pred, color = "red")
plt.show()
# Out:
# Train Set : (9, 1) (9, 1)
# Test Set  : (3, 1) (3, 1)
# Intercept of Regression 	: y =  [0.45151869]
# Coefficients of Regression 	: X =  [[0.54451308]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.39489833203529623
# Mean Squared Error (MSE) 	: 57746.016059289555
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.9887674842901676
# Mean Squared Error (MSE) 	: 3483.559449217218

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=62586f1a-5f5e-459f-afe7-2b73319ce813' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
